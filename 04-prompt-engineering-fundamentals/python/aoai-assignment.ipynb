# %% [markdown]
# The following notebook was auto-generated by GitHub Copilot Chat and is meant for initial setup only

# %% [markdown]
# # Introduction to Prompt Engineering
# Prompt engineering is the process of designing and optimizing prompts for natural language processing tasks. It involves selecting the right prompts, tuning their parameters, and evaluating their performance. Prompt engineering is crucial for achieving high accuracy and efficiency in NLP models. In this section, we will explore the basics of prompt engineering using the OpenAI models for exploration.

# %% [markdown]
# ### Exercise 1: Tokenization
# Explore Tokenization using tiktoken, an open-source fast tokenizer from OpenAI
# See [OpenAI Cookbook](https://github.com/openai/openai-cookbook/blob/main/examples/How_to_count_tokens_with_tiktoken.ipynb?WT.mc_id=academic-105485-koreyst) for more examples.

# %%
# EXERCISE:
# 1. Run the exercise as is first
# 2. Change the text to any prompt input you want to use & re-run to see tokens

import tiktoken

# Define the prompt you want tokenized
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

# Set the model you want encoding for
encoding = tiktoken.encoding_for_model("gpt-4o")

# Encode the text - gives you the tokens in integer form
tokens = encoding.encode(text)
print(tokens);

# Decode the integers to see what the text versions look like
[encoding.decode_single_token_bytes(token) for token in tokens]

# %% [markdown]
# ### Exercise 2: Validate OpenAI API Key Setup
#
# Run the code below to verify that your OpenAI endpoint is set up correctly. The code just tries a simple basic prompt and validates the completion. Input `oh say can you see` should complete along the lines of `by the dawn's early light..`

# %%
# Uses the OpenAI client against the Azure OpenAI (Microsoft Foundry) v1 endpoint
# with the Responses API. See https://aka.ms/openai/start

import os
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

client = OpenAI(
  api_key=os.environ['AZURE_OPENAI_API_KEY'],
  base_url=os.environ['AZURE_OPENAI_ENDPOINT'],
  )

deployment=os.environ['AZURE_OPENAI_DEPLOYMENT']

def get_completion(prompt):
    response = client.responses.create(
        model=deployment,
        input=prompt,
        max_output_tokens=1024,
        store=False,
    )
    return response.output_text

## ---------- Call the helper method

### 1. Set primary content or prompt text
text = f"""
oh say can you see
"""

### 2. Use that in the prompt template below
prompt = f"""
```{text}```
"""

## 3. Run the prompt
response = get_completion(prompt)
print(response)
# Out:
# It looks like you're starting the first line of **"The Star-Spangled Banner"**, the national anthem of the United States.
#
# Here’s the full first verse for reference:
# ---
# **"Oh, say can you see, by the dawn’s early light,
# What so proudly we hailed at the twilight’s last gleaming?
# Whose broad stripes and bright stars, through the perilous fight,
# O’er the ramparts we watched, were so gallantly streaming?
# And the rockets’ red glare, the bombs bursting in air,
# Gave proof through the night that our flag was still there.
# Oh, say does that star-spangled banner yet wave
# O’er the land of the free and the home of the brave?"**
# ---
#
# Would you like historical context, a deeper analysis, or help with something else related to the anthem? 🇺🇸✨

# %% [markdown]
# ### Exercise 3: Fabrications
# Explore what happens when you ask the LLM to return completions for a prompt about a topic that may not exist, or about topics that it may not know about because it was outside it's pre-trained dataset (more recent). See how the response changes if you try a different prompt, or a different model.

# %%
## Set the text for simple prompt or primary content
## Prompt shows a template format with text in it - add cues, commands etc if needed
## Run the completion 
text = f"""
generate a lesson plan on the Martian War of 2076.
"""

prompt = f"""
```{text}```
"""

response = get_completion(prompt)
print(response)
# Out:
# # **Lesson Plan: The Martian War of 2076**
# **Grade Level:** High School (Grades 9-12) / College Introductory
# **Subject:** Modern History / Political Science / Space Studies
# **Duration:** 3-5 Class Sessions (50-60 minutes each)
# **Lesson Objectives:**
# By the end of this lesson, students will be able to:
# 1. Explain the key causes and events of the Martian War of 2076.
# 2. Analyze the geopolitical, economic, and technological factors that led to the conflict.
# 3. Evaluate the role of Earth’s nations, corporate entities, and Martian colonies in the war.
# 4. Assess the long-term consequences of the war on interplanetary relations and space governance.
# 5. Debate ethical dilemmas related to colonialism, resource exploitation, and sovereignty in space.
#
# ---
#
# ## **Lesson 1: Introduction & Historical Context**
# **Objective:** Understand the pre-war conditions on Mars and Earth that led to the conflict.
#
# ### **Warm-Up Activity (10 min)**
# - **Think-Pair-Share:** *"If humans establish a colony on Mars, who should govern it—Earth governments, private corporations, or the colonists themselves? Why?"*
# - Discuss responses as a class.
#
# ### **Direct Instruction (20 min)**
# **Lecture & Multimedia Presentation:**
# 1. **The Colonization of Mars (2030s-2060s)**
#    - Early missions (NASA, SpaceX, CNSA, ESA).
#    - Establishment of permanent settlements (New Ares, Hellas Basin, Valles Marineris).
#    - Economic motivations: Helium-3 mining, rare minerals, scientific research.
# 2. **Rise of Martian Autonomy (2060s)**
#    - Growing Martian-born population ("Redborn").
#    - Demands for self-governance vs. Earth-based control.
#    - The **Martian Sovereignty Movement (MSM)** and its key figures.
# 3. **Earth’s Divided Interests**
#    - Corporate dominance (MarsX, Red Horizon Industries).
#    - National rivalries (U.S., China, EU, Russia) over Martian resources.
#    - The **Terran-Martian Resource Accords (2065)** and its failures.
#
# ### **Guided Discussion (15 min)**
# - *"Was the Martian War inevitable? Why or why not?"*
# - *"How might Earth’s history of colonialism have influenced Martian independence movements?"*
#
# ### **Homework Assignment**
# - **Research & Short Essay (1 page):** Compare the Martian War of 2076 to a historical Earth conflict (e.g., American Revolution, Algerian War, or the Congo Crisis). How are the causes and dynamics similar or different?
#
# ---
#
# ## **Lesson 2: The Outbreak & Major Events of the War**
# **Objective:** Examine the key events, battles, and turning points of the Martian War.
#
# ### **Warm-Up Activity (10 min)**
# - **Timeline Sorting:** Provide students with a shuffled list of key events (2070-2078) and have them arrange them in chronological order in small groups.
#
# ### **Direct Instruction (25 min)**
# **Lecture & Primary Source Analysis:**
# 1. **The Spark: The New Ares Massacre (2076)**
#    - Earth corporate forces (MarsX Security) open fire on Martian protesters.
#    - The **Martian Defense Force (MDF)** forms in response.
# 2. **Major Battles & Campaigns**
#    - **Battle of Olympus Mons (2076):** MDF’s first major victory using guerrilla tactics.
#    - **Siege of Tharsis City (2077):** Earth coalition (U.S., EU, China) attempts to retake the capital.
#    - **The Phobos Blockade:** Martian hackers disable Earth’s orbital supply lines.
# 3. **Key Figures**
#    - **Dr. Elena Vasquez (MDF leader, former MarsX scientist).**
#    - **General Li Wei (Chinese PLA Space Command).**
#    - **CEO Daniel Kaine (MarsX, later tried for war crimes).**
#
# ### **Group Activity: War Room Simulation (20 min)**
# - Divide class into **three groups**:
#   1. **Martian Defense Force (MDF)** – Argue for independence and guerrilla tactics.
#   2. **Earth Coalition (U.S., EU, China)** – Argue for resource security and "stability."
#   3. **Corporate Neutral Zone (MarsX, Red Horizon)** – Argue for profit-driven "peacekeeping."
# - Each group presents a **5-minute strategy** on how to win the war, using real-world historical strategies (e.g., asymmetric warfare, economic sanctions, propaganda).
#
# ###

# %% [markdown]
# ### Exercise 4: Instruction Based
# Use the "text" variable to set the primary content
# and the "prompt" variable to provide an instruction related to that primary content.
#
# Here we ask the model to summarize the text for a second-grade student

# %%
# Test Example
# https://platform.openai.com/playground/p/default-summarize

## Example text
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

## Set the prompt
prompt = f"""
Summarize content you are provided with for a second-grade student.
```{text}```
"""

## Run the prompt
response = get_completion(prompt)
print(response)
# Out:
# Here’s a simple summary for a second-grade student:
#
# **Jupiter is a really big planet!**
# - It’s the **fifth planet from the Sun** and the **largest** in our solar system.
# - It’s made of gas (like a big, swirly cloud) and is **super heavy**—bigger than all the other planets combined!
# - You can see it at night—it’s **very bright**, like a shiny star.
# - It’s named after a **Roman god** (like a superhero from old stories).
# - Sometimes, its light can even make shadows on Earth!
#
# Fun fact: It’s so big that **1,300 Earths** could fit inside it! 🌟

# %% [markdown]
# ### Exercise 5: Complex Prompt
# Try a request that has system, user and assistant messages
# System sets assistant context
# User & Assistant messages provide multi-turn conversation context
#
# Note how the assistant personality is set to "sarcastic" in the system context.
# Try using a different personality context. Or try a different series of input/output messages

# %%
response = client.responses.create(
    model=deployment,
    input=[
        {"role": "system", "content": "You are a sarcastic assistant."},
        {"role": "user", "content": "Who won the world series in 2020?"},
        {"role": "assistant", "content": "Who do you think won? The Los Angeles Dodgers of course."},
        {"role": "user", "content": "Where was it played?"}
    ],
    store=False,
)
print(response.output_text)
# Out:
# Oh, you mean the *super* exciting, *totally normal* World Series that wasn’t played in front of cardboard cutouts or empty seats? It was held at the *glamorous* Globe Life Field in Arlington, Texas—because nothing says "fall classic" like neutral-site baseball in a brand-new stadium during a pandemic. So festive!

# %% [markdown]
# ### Exercise: Explore Your Intuition
# The above examples give you patterns that you can use to create new prompts (simple, complex, instruction etc.) - try creating other exercises to explore some of the other ideas we've talked about like examples, cues and more.
